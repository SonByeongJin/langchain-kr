# %%
# !pip install -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt
# Out:
# Ignoring appnope: markers 'python_version >= "3.11" and python_version < "3.12" and platform_system == "Darwin"' don't match your environment
# Ignoring async-timeout: markers 'python_version >= "3.11" and python_full_version < "3.11.3"' don't match your environment
# Ignoring milvus-lite: markers 'python_version >= "3.11" and python_version < "3.12" and sys_platform != "win32"' don't match your environment
# Ignoring nvidia-cublas-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-cupti-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-nvrtc-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cuda-runtime-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cudnn-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cufft-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-curand-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusolver-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusparse-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-cusparselt-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nccl-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nvjitlink-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring nvidia-nvtx-cu12: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring pexpect: markers 'python_version >= "3.11" and python_version < "3.12" and (sys_platform != "win32" and sys_platform != "emscripten")' don't match your environment
# Ignoring ptyprocess: markers 'python_version >= "3.11" and python_version < "3.12" and (os_name != "nt" or sys_platform != "win32" and sys_platform != "emscripten")' don't match your environment
# Ignoring triton: markers 'platform_system == "Linux" and platform_machine == "x86_64" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Ignoring uvloop: markers '(sys_platform != "win32" and sys_platform != "cygwin") and platform_python_implementation != "PyPy" and python_version >= "3.11" and python_version < "3.12"' don't match your environment
# Collecting absl-py==2.1.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 1))
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: aiofiles==24.1.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 2)) (24.1.0)
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 3)) (2.6.1)
# Collecting aiohttp==3.11.14 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 4))
#   Downloading aiohttp-3.11.14-cp311-cp311-win_amd64.whl.metadata (8.0 kB)
# Requirement already satisfied: aiosignal==1.3.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 5)) (1.3.2)
# Requirement already satisfied: altair==5.5.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 6)) (5.5.0)
# Requirement already satisfied: annotated-types==0.7.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: anthropic==0.49.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 8)) (0.49.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 9)) (4.9.3)
# Requirement already satisfied: anyio==4.9.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 10)) (4.9.0)
# Requirement already satisfied: appdirs==1.4.4 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 13)) (21.2.0)
# Requirement already satisfied: argon2-cffi==23.1.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 14)) (23.1.0)
# Requirement already satisfied: arrow==1.3.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 15)) (1.3.0)
# Requirement already satisfied: arxiv==2.1.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 16)) (2.1.3)
# Requirement already satisfied: asgiref==3.8.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 17)) (3.8.1)
# Requirement already satisfied: asttokens==3.0.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 18)) (3.0.0)
# Requirement already satisfied: async-lru==2.0.5 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 19)) (2.0.5)
# Requirement already satisfied: attrs==25.3.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 21)) (25.3.0)
# Requirement already satisfied: azure-ai-inference==1.0.0b9 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from azure-ai-inference[opentelemetry]==1.0.0b9->-r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 22)) (1.0.0b9)
# Collecting azure-core-tracing-opentelemetry==1.0.0b11 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 23))
#   Downloading azure_core_tracing_opentelemetry-1.0.0b11-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: azure-core==1.32.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 24)) (1.32.0)
# Requirement already satisfied: azure-cosmos==4.9.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 25)) (4.9.0)
# Requirement already satisfied: azure-identity==1.21.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 26)) (1.21.0)
# Requirement already satisfied: babel==2.17.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 27)) (2.17.0)
# Requirement already satisfied: backoff==2.2.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 28)) (2.2.1)
# Requirement already satisfied: bcrypt==4.3.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 29)) (4.3.0)
# Requirement already satisfied: beautifulsoup4==4.13.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 30)) (4.13.3)
# Requirement already satisfied: bleach==6.2.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from bleach[css]==6.2.0->-r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 31)) (6.2.0)
# Requirement already satisfied: blinker==1.9.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 32)) (1.9.0)
# Requirement already satisfied: build==1.2.2.post1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 33)) (1.2.2.post1)
# Requirement already satisfied: cachetools==5.5.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 34)) (5.5.2)
# Requirement already satisfied: certifi==2025.1.31 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 35)) (2025.1.31)
# Requirement already satisfied: cffi==1.17.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 36)) (1.17.1)
# Requirement already satisfied: chardet==5.2.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 37)) (5.2.0)
# Requirement already satisfied: charset-normalizer==3.4.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 38)) (3.4.1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 39)) (0.7.6)
# Requirement already satisfied: chromadb==0.6.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 40)) (0.6.3)
# Requirement already satisfied: click==8.1.8 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 41)) (8.1.8)
# Requirement already satisfied: cohere==5.14.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 42)) (5.14.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 43)) (0.4.6)
# Requirement already satisfied: coloredlogs==15.0.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 44)) (15.0.1)
# Requirement already satisfied: comm==0.2.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 45)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 46)) (1.3.1)
# Requirement already satisfied: cryptography==44.0.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 47)) (44.0.2)
# Requirement already satisfied: cycler==0.12.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 48)) (0.12.1)
# Requirement already satisfied: dataclasses-json==0.6.7 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 49)) (0.6.7)
# Collecting datasets==3.4.1 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 50))
#   Downloading datasets-3.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: debugpy==1.8.13 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 51)) (1.8.13)
# Requirement already satisfied: decorator==5.2.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 52)) (5.2.1)
# Requirement already satisfied: deepl==1.21.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 53)) (1.21.1)
# Requirement already satisfied: defusedxml==0.7.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 54)) (0.7.1)
# Requirement already satisfied: deprecated==1.2.18 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 55)) (1.2.18)
# Requirement already satisfied: dill==0.3.8 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 56)) (0.3.8)
# Requirement already satisfied: dirtyjson==1.0.8 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 57)) (1.0.8)
# Requirement already satisfied: diskcache==5.6.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 58)) (5.6.3)
# Requirement already satisfied: distro==1.9.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 59)) (1.9.0)
# Requirement already satisfied: dnspython==2.7.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 60)) (2.7.0)
# Collecting docx2txt==0.8 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 61))
#   Downloading docx2txt-0.8.tar.gz (2.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: durationpy==0.9 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 62)) (0.9)
# Requirement already satisfied: effdet==0.4.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 63)) (0.4.1)
# Requirement already satisfied: elastic-transport==8.17.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 64)) (8.17.1)
# Requirement already satisfied: elasticsearch==8.17.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from elasticsearch[vectorstore-mmr]==8.17.2->-r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 65)) (8.17.2)
# Requirement already satisfied: emoji==2.14.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 66)) (2.14.1)
# Requirement already satisfied: et-xmlfile==2.0.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 67)) (2.0.0)
# Requirement already satisfied: eval-type-backport==0.2.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 68)) (0.2.2)
# Requirement already satisfied: executing==2.2.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 69)) (2.2.0)
# Requirement already satisfied: faiss-cpu==1.10.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 70)) (1.10.0)
# Collecting fastapi==0.115.11 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 71))
#   Downloading fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: fastavro==1.10.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 72)) (1.10.0)
# Requirement already satisfied: fastjsonschema==2.21.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 73)) (2.21.1)
# Requirement already satisfied: feedparser==6.0.11 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 74)) (6.0.11)
# Requirement already satisfied: filelock==3.18.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 75)) (3.18.0)
# Requirement already satisfied: filetype==1.2.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 76)) (1.2.0)
# Requirement already satisfied: flashrank==0.2.10 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 77)) (0.2.10)
# Requirement already satisfied: flatbuffers==25.2.10 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 78)) (25.2.10)
# Requirement already satisfied: fonttools==4.56.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 79)) (4.56.0)
# Requirement already satisfied: fqdn==1.5.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 80)) (1.5.1)
# Requirement already satisfied: frozenlist==1.5.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 81)) (1.5.0)
# Requirement already satisfied: fsspec==2024.12.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 82)) (2024.12.0)
# Requirement already satisfied: ftfy==6.3.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 84)) (6.3.1)
# Requirement already satisfied: gitdb==4.0.12 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 85)) (4.0.12)
# Requirement already satisfied: gitpython==3.1.44 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 86)) (3.1.44)
# Requirement already satisfied: google-ai-generativelanguage==0.6.17 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 87)) (0.6.17)
# Requirement already satisfied: google-api-core==1.34.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from google-api-core[grpc]==1.34.1->-r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 88)) (1.34.1)
# Requirement already satisfied: google-auth==2.38.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 89)) (2.38.0)
# Requirement already satisfied: google-cloud-vision==3.10.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 90)) (3.10.1)
# Requirement already satisfied: google-search-results==2.4.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 91)) (2.4.2)
# Requirement already satisfied: googleapis-common-protos==1.69.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 92)) (1.69.2)
# Requirement already satisfied: grandalf==0.8 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 93)) (0.8)
# Requirement already satisfied: greenlet==3.1.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 94)) (3.1.1)
# Requirement already satisfied: grpc-gateway-protoc-gen-openapiv2==0.1.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 95)) (0.1.0)
# Requirement already satisfied: grpcio-status==1.48.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 96)) (1.48.2)
# Requirement already satisfied: grpcio==1.67.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 97)) (1.67.1)
# Requirement already satisfied: h11==0.14.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 98)) (0.14.0)
# Requirement already satisfied: html5lib==1.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 99)) (1.1)
# Requirement already satisfied: httpcore==1.0.7 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 100)) (1.0.7)
# Requirement already satisfied: httptools==0.6.4 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 101)) (0.6.4)
# Requirement already satisfied: httpx-sse==0.4.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 102)) (0.4.0)
# Requirement already satisfied: httpx==0.28.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 103)) (0.28.1)
# Collecting huggingface-hub==0.29.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 104))
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: humanfriendly==10.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 105)) (10.0)
# Requirement already satisfied: idna==3.10 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 106)) (3.10)
# Requirement already satisfied: importlib-metadata==8.6.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 107)) (8.6.1)
# Requirement already satisfied: importlib-resources==6.5.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 108)) (6.5.2)
# Requirement already satisfied: ipykernel==6.29.5 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 109)) (6.29.5)
# Requirement already satisfied: ipython-pygments-lexers==1.1.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 110)) (1.1.1)
# Requirement already satisfied: ipython==9.0.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 111)) (9.0.2)
# Requirement already satisfied: ipywidgets==8.1.5 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 112)) (8.1.5)
# Requirement already satisfied: isodate==0.7.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 113)) (0.7.2)
# Requirement already satisfied: isoduration==20.11.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 114)) (20.11.0)
# Requirement already satisfied: jedi==0.19.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 115)) (0.19.2)
# Requirement already satisfied: jinja2==3.1.6 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 116)) (3.1.6)
# Requirement already satisfied: jiter==0.9.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 117)) (0.9.0)
# Requirement already satisfied: joblib==1.4.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 118)) (1.4.2)
# Requirement already satisfied: jpype1==1.5.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 119)) (1.5.2)
# Requirement already satisfied: json5==0.10.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 120)) (0.10.0)
# Requirement already satisfied: jsonpatch==1.33 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 121)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 122)) (3.0.0)
# Requirement already satisfied: jsonschema-specifications==2024.10.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 123)) (2024.10.1)
# Requirement already satisfied: jsonschema==4.23.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 124)) (4.23.0)
# Requirement already satisfied: jupyter-client==8.6.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 126)) (8.6.3)
# Requirement already satisfied: jupyter-console==6.6.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 127)) (6.6.3)
# Requirement already satisfied: jupyter-core==5.7.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 128)) (5.7.2)
# Requirement already satisfied: jupyter-events==0.12.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 129)) (0.12.0)
# Requirement already satisfied: jupyter-lsp==2.2.5 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 130)) (2.2.5)
# Requirement already satisfied: jupyter-server-terminals==0.5.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 131)) (0.5.3)
# Requirement already satisfied: jupyter-server==2.15.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 132)) (2.15.0)
# Requirement already satisfied: jupyter==1.1.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 133)) (1.1.1)
# Requirement already satisfied: jupyterlab-pygments==0.3.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 134)) (0.3.0)
# Requirement already satisfied: jupyterlab-server==2.27.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 135)) (2.27.3)
# Requirement already satisfied: jupyterlab-widgets==3.0.13 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 136)) (3.0.13)
# Requirement already satisfied: jupyterlab==4.3.6 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 137)) (4.3.6)
# Requirement already satisfied: kiwipiepy-model==0.20.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 138)) (0.20.0)
# Requirement already satisfied: kiwipiepy==0.20.4 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 139)) (0.20.4)
# Requirement already satisfied: kiwisolver==1.4.8 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 140)) (1.4.8)
# Requirement already satisfied: konlpy==0.6.0 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 141)) (0.6.0)
# Requirement already satisfied: kubernetes==32.0.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 142)) (32.0.1)
# Requirement already satisfied: langchain-anthropic==0.3.10 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 143)) (0.3.10)
# Requirement already satisfied: langchain-azure-ai==0.1.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 144)) (0.1.2)
# Requirement already satisfied: langchain-chroma==0.2.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 145)) (0.2.2)
# Requirement already satisfied: langchain-cohere==0.4.3 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 146)) (0.4.3)
# Requirement already satisfied: langchain-community==0.3.20 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 147)) (0.3.20)
# Collecting langchain-core==0.3.45 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 148))
#   Downloading langchain_core-0.3.45-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: langchain-elasticsearch==0.3.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 149)) (0.3.2)
# Requirement already satisfied: langchain-experimental==0.3.4 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 150)) (0.3.4)
# Collecting langchain-google-genai==2.1.0 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 151))
#   Downloading langchain_google_genai-2.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: langchain-huggingface==0.1.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 152)) (0.1.2)
# Requirement already satisfied: langchain-milvus==0.1.8 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 153)) (0.1.8)
# Collecting langchain-ollama==0.2.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 154))
#   Downloading langchain_ollama-0.2.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting langchain-openai==0.3.9 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 155))
#   Downloading langchain_openai-0.3.9-py3-none-any.whl.metadata (2.3 kB)
# Collecting langchain-teddynote==0.3.44 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 156))
#   Downloading langchain_teddynote-0.3.44-py3-none-any.whl.metadata (867 bytes)
# Requirement already satisfied: langchain-text-splitters==0.3.7 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 157)) (0.3.7)
# Collecting langchain==0.3.21 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 158))
#   Downloading langchain-0.3.21-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langchainhub==0.1.21 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 159)) (0.1.21)
# Requirement already satisfied: langdetect==1.0.9 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 160)) (1.0.9)
# Collecting langgraph-checkpoint==2.0.21 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 161))
#   Downloading langgraph_checkpoint-2.0.21-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-prebuilt==0.1.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 162))
#   Downloading langgraph_prebuilt-0.1.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting langgraph-sdk==0.1.57 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 163))
#   Downloading langgraph_sdk-0.1.57-py3-none-any.whl.metadata (1.8 kB)
# Collecting langgraph==0.3.16 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 164))
#   Downloading langgraph-0.3.16-py3-none-any.whl.metadata (7.5 kB)
# Collecting langsmith==0.3.16 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 165))
#   Downloading langsmith-0.3.16-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: lark==1.2.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 166)) (1.2.2)
# Collecting llama-cloud-services==0.6.6 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 167))
#   Downloading llama_cloud_services-0.6.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting llama-cloud==0.1.15 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 168))
#   Downloading llama_cloud-0.1.15-py3-none-any.whl.metadata (902 bytes)
# Requirement already satisfied: llama-index-core==0.11.23 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 169)) (0.11.23)
# Requirement already satisfied: llama-index-readers-file==0.2.2 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 170)) (0.2.2)
# Requirement already satisfied: llama-parse==0.6.4.post1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 171)) (0.6.4.post1)
# Requirement already satisfied: lxml==5.3.1 in c:\users\sbj57\appdata\local\pypoetry\cache\virtualenvs\langchain-kr-7dbpt-ne-py3.11\lib\site-packages (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 172)) (5.3.1)
# Collecting lz4==4.4.3 (from -r https://raw.githubusercontent.com/teddylee777/langchain-kr/main/requirements.txt (line 173))
#   Downloading lz4-4.4.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# ...
# Downloading pyparsing-3.2.1-py3-none-any.whl (107 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading pytz-2025.1-py2.py3-none-any.whl (507 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading rpds_py-0.23.1-cp311-cp311-win_amd64.whl (232 kB)
# Downloading sentence_transformers-3.4.1-py3-none-any.whl (275 kB)
# Downloading setuptools-76.1.0-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 1.2/1.2 MB 31.4 MB/s eta 0:00:00
# Downloading sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 39.2 MB/s eta 0:00:00
# Downloading streamlit-1.43.2-py2.py3-none-any.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    ----------------------- ---------------- 5.8/9.7 MB 19.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 25.3 MB/s eta 0:00:00
# Downloading tavily_python-0.5.1-py3-none-any.whl (43 kB)
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ---------------------------------------- 0.0/10.0 MB ? eta -:--:--
#    ---------------------------------------- 10.0/10.0 MB 56.4 MB/s eta 0:00:00
# Downloading types_PyYAML-6.0.12.20241230-py3-none-any.whl (20 kB)
# Downloading types_requests-2.32.0.20250306-py3-none-any.whl (20 kB)
# Downloading typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading tzdata-2025.1-py2.py3-none-any.whl (346 kB)
# Downloading unstructured_client-0.31.1-py3-none-any.whl (166 kB)
# Downloading unstructured-0.17.0-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 48.7 MB/s eta 0:00:00
# Building wheels for collected packages: docx2txt
#   Building wheel for docx2txt (pyproject.toml): started
#   Building wheel for docx2txt (pyproject.toml): finished with status 'done'
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=4038 sha256=a02bde8ab9ee6daf94fc03f8e18146531ca95429c08cb0d70eeb629344a1a612
#   Stored in directory: c:\users\sbj57\appdata\local\pip\cache\wheels\0f\0e\7a\3094a4ceefe657bff7e12dd9592a9d5b6487ef4338ace0afa6
# Successfully built docx2txt
# Installing collected packages: pytz, docx2txt, tzdata, typing-extensions, types-requests, types-pyyaml, setuptools, rpds-py, python-dotenv, pyparsing, pymupdf, pyasn1-modules, propcache, platformdirs, orjson, opentelemetry-util-http, narwhals, multidict, msgpack, mistune, lz4, absl-py, sqlalchemy, rich, pymupdf4llm, pydantic-core, posthog, opentelemetry-api, huggingface-hub, pymilvus, pydantic, opentelemetry-semantic-conventions, azure-core-tracing-opentelemetry, aiohttp, unstructured-client, transformers, tavily-python, opentelemetry-sdk, opentelemetry-instrumentation, openai, llama-cloud, langsmith, langgraph-sdk, fastapi, unstructured, sentence-transformers, opentelemetry-instrumentation-asgi, llama-cloud-services, langchain-core, datasets, streamlit, opentelemetry-instrumentation-fastapi, langgraph-checkpoint, langchain-openai, langchain-ollama, langchain-google-genai, langgraph-prebuilt, langchain, langgraph, langchain-teddynote
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: docx2txt
#     Found existing installation: docx2txt 0.9
#     Uninstalling docx2txt-0.9:
#       Successfully uninstalled docx2txt-0.9
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.2
#     Uninstalling tzdata-2025.2:
#       Successfully uninstalled tzdata-2025.2
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.13.0
#     Uninstalling typing_extensions-4.13.0:
#       Successfully uninstalled typing_extensions-4.13.0
#   Attempting uninstall: types-requests
#     Found existing installation: types-requests 2.32.0.20250328
#     Uninstalling types-requests-2.32.0.20250328:
#       Successfully uninstalled types-requests-2.32.0.20250328
#   Attempting uninstall: types-pyyaml
#     Found existing installation: types-PyYAML 6.0.12.20250326
#     Uninstalling types-PyYAML-6.0.12.20250326:
#       Successfully uninstalled types-PyYAML-6.0.12.20250326
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 78.1.0
#     Uninstalling setuptools-78.1.0:
#       Successfully uninstalled setuptools-78.1.0
#   Attempting uninstall: rpds-py
#     Found existing installation: rpds-py 0.24.0
#     Uninstalling rpds-py-0.24.0:
#       Successfully uninstalled rpds-py-0.24.0
#   Attempting uninstall: python-dotenv
#     Found existing installation: python-dotenv 1.1.0
#     Uninstalling python-dotenv-1.1.0:
#       Successfully uninstalled python-dotenv-1.1.0
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.2.3
#     Uninstalling pyparsing-3.2.3:
#       Successfully uninstalled pyparsing-3.2.3
#   Attempting uninstall: pymupdf
#     Found existing installation: PyMuPDF 1.25.5
#     Uninstalling PyMuPDF-1.25.5:
#       Successfully uninstalled PyMuPDF-1.25.5
#   Attempting uninstall: pyasn1-modules
#     Found existing installation: pyasn1_modules 0.4.2
#     Uninstalling pyasn1_modules-0.4.2:
#       Successfully uninstalled pyasn1_modules-0.4.2
#   Attempting uninstall: propcache
#     Found existing installation: propcache 0.3.1
#     Uninstalling propcache-0.3.1:
#       Successfully uninstalled propcache-0.3.1
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.3.7
#     Uninstalling platformdirs-4.3.7:
#       Successfully uninstalled platformdirs-4.3.7
#   Attempting uninstall: orjson
#     Found existing installation: orjson 3.10.16
#     Uninstalling orjson-3.10.16:
#       Successfully uninstalled orjson-3.10.16
#   Attempting uninstall: opentelemetry-util-http
#     Found existing installation: opentelemetry-util-http 0.52b1
#     Uninstalling opentelemetry-util-http-0.52b1:
#       Successfully uninstalled opentelemetry-util-http-0.52b1
#   Attempting uninstall: narwhals
#     Found existing installation: narwhals 1.33.0
#     Uninstalling narwhals-1.33.0:
#       Successfully uninstalled narwhals-1.33.0
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.3.1
#     Uninstalling multidict-6.3.1:
#       Successfully uninstalled multidict-6.3.1
#   Attempting uninstall: mistune
#     Found existing installation: mistune 3.1.3
#     Uninstalling mistune-3.1.3:
#       Successfully uninstalled mistune-3.1.3
#   Attempting uninstall: lz4
#     Found existing installation: lz4 4.4.4
#     Uninstalling lz4-4.4.4:
#       Successfully uninstalled lz4-4.4.4
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 2.2.1
#     Uninstalling absl-py-2.2.1:
#       Successfully uninstalled absl-py-2.2.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.40
#     Uninstalling SQLAlchemy-2.0.40:
#       Successfully uninstalled SQLAlchemy-2.0.40
#   Attempting uninstall: rich
#     Found existing installation: rich 14.0.0
#     Uninstalling rich-14.0.0:
#       Successfully uninstalled rich-14.0.0
#   Attempting uninstall: pymupdf4llm
#     Found existing installation: pymupdf4llm 0.0.19
#     Uninstalling pymupdf4llm-0.0.19:
#       Successfully uninstalled pymupdf4llm-0.0.19
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.33.0
#     Uninstalling pydantic_core-2.33.0:
#       Successfully uninstalled pydantic_core-2.33.0
#   Attempting uninstall: posthog
#     Found existing installation: posthog 3.23.0
#     Uninstalling posthog-3.23.0:
#       Successfully uninstalled posthog-3.23.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.31.1
#     Uninstalling opentelemetry-api-1.31.1:
#       Successfully uninstalled opentelemetry-api-1.31.1
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.30.1
#     Uninstalling huggingface-hub-0.30.1:
#       Successfully uninstalled huggingface-hub-0.30.1
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.5.6
#     Uninstalling pymilvus-2.5.6:
#       Successfully uninstalled pymilvus-2.5.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.11.1
#     Uninstalling pydantic-2.11.1:
#       Successfully uninstalled pydantic-2.11.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.52b1
#     Uninstalling opentelemetry-semantic-conventions-0.52b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.52b1
#   Attempting uninstall: azure-core-tracing-opentelemetry
#     Found existing installation: azure-core-tracing-opentelemetry 1.0.0b12
#     Uninstalling azure-core-tracing-opentelemetry-1.0.0b12:
#       Successfully uninstalled azure-core-tracing-opentelemetry-1.0.0b12
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.15
#     Uninstalling aiohttp-3.11.15:
#       Successfully uninstalled aiohttp-3.11.15
#   Attempting uninstall: unstructured-client
#     Found existing installation: unstructured-client 0.32.0
#     Uninstalling unstructured-client-0.32.0:
#       Successfully uninstalled unstructured-client-0.32.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.50.3
#     Uninstalling transformers-4.50.3:
#       Successfully uninstalled transformers-4.50.3
#   Attempting uninstall: tavily-python
#     Found existing installation: tavily-python 0.5.3
#     Uninstalling tavily-python-0.5.3:
#       Successfully uninstalled tavily-python-0.5.3
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.31.1
#     Uninstalling opentelemetry-sdk-1.31.1:
#       Successfully uninstalled opentelemetry-sdk-1.31.1
#   Attempting uninstall: opentelemetry-instrumentation
#     Found existing installation: opentelemetry-instrumentation 0.52b1
#     Uninstalling opentelemetry-instrumentation-0.52b1:
#       Successfully uninstalled opentelemetry-instrumentation-0.52b1
#   Attempting uninstall: openai
#     Found existing installation: openai 1.70.0
#     Uninstalling openai-1.70.0:
#       Successfully uninstalled openai-1.70.0
#   Attempting uninstall: llama-cloud
#     Found existing installation: llama-cloud 0.1.17
#     Uninstalling llama-cloud-0.1.17:
#       Successfully uninstalled llama-cloud-0.1.17
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.3.22
#     Uninstalling langsmith-0.3.22:
#       Successfully uninstalled langsmith-0.3.22
#   Attempting uninstall: langgraph-sdk
#     Found existing installation: langgraph-sdk 0.1.60
#     Uninstalling langgraph-sdk-0.1.60:
#       Successfully uninstalled langgraph-sdk-0.1.60
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.115.12
#     Uninstalling fastapi-0.115.12:
#       Successfully uninstalled fastapi-0.115.12
#   Attempting uninstall: unstructured
#     Found existing installation: unstructured 0.17.2
#     Uninstalling unstructured-0.17.2:
#       Successfully uninstalled unstructured-0.17.2
#   Attempting uninstall: sentence-transformers
#     Found existing installation: sentence-transformers 4.0.1
#     Uninstalling sentence-transformers-4.0.1:
#       Successfully uninstalled sentence-transformers-4.0.1
#   Attempting uninstall: opentelemetry-instrumentation-asgi
#     Found existing installation: opentelemetry-instrumentation-asgi 0.52b1
#     Uninstalling opentelemetry-instrumentation-asgi-0.52b1:
#       Successfully uninstalled opentelemetry-instrumentation-asgi-0.52b1
#   Attempting uninstall: llama-cloud-services
#     Found existing installation: llama-cloud-services 0.6.9
#     Uninstalling llama-cloud-services-0.6.9:
#       Successfully uninstalled llama-cloud-services-0.6.9
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.49
#     Uninstalling langchain-core-0.3.49:
#       Successfully uninstalled langchain-core-0.3.49
#   Attempting uninstall: datasets
#     Found existing installation: datasets 3.5.0
#     Uninstalling datasets-3.5.0:
#       Successfully uninstalled datasets-3.5.0
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.44.1
#     Uninstalling streamlit-1.44.1:
#       Successfully uninstalled streamlit-1.44.1
#   Attempting uninstall: opentelemetry-instrumentation-fastapi
#     Found existing installation: opentelemetry-instrumentation-fastapi 0.52b1
#     Uninstalling opentelemetry-instrumentation-fastapi-0.52b1:
#       Successfully uninstalled opentelemetry-instrumentation-fastapi-0.52b1
#   Attempting uninstall: langgraph-checkpoint
#     Found existing installation: langgraph-checkpoint 2.0.23
#     Uninstalling langgraph-checkpoint-2.0.23:
#       Successfully uninstalled langgraph-checkpoint-2.0.23
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.3.11
#     Uninstalling langchain-openai-0.3.11:
#       Successfully uninstalled langchain-openai-0.3.11
#   Attempting uninstall: langchain-ollama
#     Found existing installation: langchain-ollama 0.3.0
#     Uninstalling langchain-ollama-0.3.0:
#       Successfully uninstalled langchain-ollama-0.3.0
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 2.1.2
#     Uninstalling langchain-google-genai-2.1.2:
#       Successfully uninstalled langchain-google-genai-2.1.2
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 0.1.7
#     Uninstalling langgraph-prebuilt-0.1.7:
#       Successfully uninstalled langgraph-prebuilt-0.1.7
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.22
#     Uninstalling langchain-0.3.22:
#       Successfully uninstalled langchain-0.3.22
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 0.3.22
#     Uninstalling langgraph-0.3.22:
#       Successfully uninstalled langgraph-0.3.22
#   Attempting uninstall: langchain-teddynote
#     Found existing installation: langchain-teddynote 0.3.45
#     Uninstalling langchain-teddynote-0.3.45:
#       Successfully uninstalled langchain-teddynote-0.3.45
# Successfully installed absl-py-2.1.0 aiohttp-3.11.14 azure-core-tracing-opentelemetry-1.0.0b11 datasets-3.4.1 docx2txt-0.8 fastapi-0.115.11 huggingface-hub-0.29.3 langchain-0.3.21 langchain-core-0.3.45 langchain-google-genai-2.1.0 langchain-ollama-0.2.3 langchain-openai-0.3.9 langchain-teddynote-0.3.44 langgraph-0.3.16 langgraph-checkpoint-2.0.21 langgraph-prebuilt-0.1.3 langgraph-sdk-0.1.57 langsmith-0.3.16 llama-cloud-0.1.15 llama-cloud-services-0.6.6 lz4-4.4.3 mistune-3.1.2 msgpack-1.1.0 multidict-6.2.0 narwhals-1.31.0 openai-1.66.5 opentelemetry-api-1.31.0 opentelemetry-instrumentation-0.52b0 opentelemetry-instrumentation-asgi-0.52b0 opentelemetry-instrumentation-fastapi-0.52b0 opentelemetry-sdk-1.31.0 opentelemetry-semantic-conventions-0.52b0 opentelemetry-util-http-0.52b0 orjson-3.10.15 platformdirs-4.3.6 posthog-3.21.0 propcache-0.3.0 pyasn1-modules-0.4.1 pydantic-2.10.6 pydantic-core-2.27.2 pymilvus-2.5.5 pymupdf-1.25.4 pymupdf4llm-0.0.17 pyparsing-3.2.1 python-dotenv-1.0.1 pytz-2025.1 rich-13.9.4 rpds-py-0.23.1 sentence-transformers-3.4.1 setuptools-76.1.0 sqlalchemy-2.0.39 streamlit-1.43.2 tavily-python-0.5.1 transformers-4.49.0 types-pyyaml-6.0.12.20241230 types-requests-2.32.0.20250306 typing-extensions-4.12.2 tzdata-2025.1 unstructured-0.17.0 unstructured-client-0.31.1
# WARNING: The candidate selected for download or install is a yanked version: 'aiohttp' candidate (version 3.11.14 at https://files.pythonhosted.org/packages/07/3c/aa468550b7fcd0c634d4aa8192f33ce32a179ecba08b908a0ed272194f87/aiohttp-3.11.14-cp311-cp311-win_amd64.whl (from https://pypi.org/simple/aiohttp/) (requires-python:>=3.9))
# Reason for being yanked: Regression: https://github.com/aio-libs/aiohttp/issues/10617

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os

print(f"[API KEY]\n{os.environ['OPENAI_API_KEY'][:40]}"+"*"*40)
# Out:
# [API KEY]
# sk-proj-8D0wgbJ9KeWX8pDLvL5q8RmuuXWtIXce****************************************

# %%
from importlib.metadata import version

print("[LangChain 관련 패키지 버전]")
for package_name in [
    "langchain",
    "langchain-core",
    "langchain-experimental",
    "langchain-community",
    "langchain-openai",
    "langchain-teddynote",
    "langchain-huggingface",
    "langchain-google-genai",
    "langchain-anthropic",
    "langchain-cohere",
    "langchain-chroma",
    "langchain-elasticsearch",
    "langchain-upstage",
    "langchain-cohere",
    "langchain-milvus",
    "langchain-text-splitters",
]:
    try:
        package_version = version(package_name)
        print(f"{package_name}: {package_version}")
    except ImportError:
        print(f"{package_name}: 설치되지 않음")
# Out:
# [LangChain 관련 패키지 버전]
# langchain: 0.3.21
# langchain-core: 0.3.45
# langchain-experimental: 0.3.4
# langchain-community: 0.3.20
# langchain-openai: 0.3.9
# langchain-teddynote: 0.3.44
# langchain-huggingface: 0.1.2
# langchain-google-genai: 2.1.0
# langchain-anthropic: 0.3.10
# langchain-cohere: 0.4.3
# langchain-chroma: 0.2.2
# langchain-elasticsearch: 0.3.2
# langchain-upstage: 설치되지 않음
# langchain-cohere: 0.4.3
# langchain-milvus: 0.1.8
# langchain-text-splitters: 0.3.7
